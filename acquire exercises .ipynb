# %%
from cgi import test
from lib2to3.pgen2.pgen import DFAState
from lib2to3.refactor import get_all_fix_names
import numpy as np
import seaborn as sns
import scipy.stats as stats
import pandas as pd
import matplotlib.pyplot as plt
from pydataset import data
import scipy
import os
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
import warnings
warnings.filterwarnings('ignore')
import requests

# %% [markdown]
# Exercises
# Create a new local git repository and remote repository on github named time-series-exercises. Save this work for this module in your time-series-exercises repo.
#
# The end result of this exercise should be a file named acquire.py.
#
# 1. Using the code from the lesson as a guide and the REST API from https://python.zgulde.net/api/v1/items as we did in the lesson, create a dataframe named items that has all of the data for items.
#
# 2. Do the same thing, but for stores (https://python.zgulde.net/api/v1/stores)
#
# 3. Extract the data for sales (https://python.zgulde.net/api/v1/sales). There are a lot of pages of data here, so your code will need to be a little more complex. Your code should continue fetching data from the next page until all of the data is extracted.
#
# 4. Save the data in your files to local csv files so that it will be faster to access in the future.
#
# 5. Combine the data from your three separate dataframes into one large dataframe.
#
# 6. Acquire the Open Power Systems Data for Germany, which has been rapidly expanding its renewable energy production in recent years. The data set includes country-wide totals of electricity consumption, wind power production, and solar power production for 2006-2017. You can get the data here: https://raw.githubusercontent.com/jenfly/opsd/master/opsd_germany_daily.csv
#
# 7. Make sure all the work that you have done above is reproducible. That is, you should put the code above into separate functions in the acquire.py file and be able to re-run the functions and get the same data.

# %%
import pandas as pd

import requests

# %% [markdown]
# ### 1. Using the code from the lesson as a guide and the REST API from https://python.zgulde.net/api/v1/items as we did in the lesson, create a dataframe named items that has all of the data for items.

# %% [markdown]
# Http status codes:
#
#     - 200s: everythings good
#     - 300s: redirecting
#     - 400s: you did something wrong
#     - 500s: something is wrong with the server

# %%
def items():
    # setup
    domain = 'https://python.zgulde.net'
    endpoint = '/api/v1/items'
    items = []
    #loop while our endpoint till it hits an end.
    while endpoint != None:
        #create api url
        url = domain + endpoint
        #get data
        response = requests.get(url)
        data = response.json()
        #add data to list
        items.extend(data['payload']['items'])
        #grab new endpoint
        endpoint = data['payload']['next_page']
    items = pd.DataFrame(items)
    return items
items()
# Out:
#                 item_brand  item_id  \
# 0                 Riceland        1
# 1                   Caress        2
# 2              Earths Best        3
# 3               Boars Head        4
# 4           Back To Nature        5
# 5             Sally Hansen        6
# 6       Twinings Of London        7
# 7            Lea & Perrins        8
# 8             Van De Kamps        9
# 9                    Ahold       10
# 10              Honest Tea       11
# 11                 Mueller       12
# 12   Garnier Nutritioniste       13
# 13                 Pamprin       14
# 14                   Suave       15
# 15              Burts Bees       16
# 16                   Ducal       17
# 17                  Scotch       18
# 18                 Careone       19
# 19            Usda Produce       20
# 20            Doctors Best       21
# 21           Betty Crocker       22
# 22                   Reese       23
# 23            Smart Living       24
# 24                    Hood       25
# 25               Triaminic       26
# 26                  Morton       27
# 27            Usda Produce       28
# 28                   Heinz       29
# 29                 Petmate       30
# 30        Zhenas Gypsy Tea       31
# 31                Barefoot       32
# 32         The First Years       33
# 33                   Halls       34
# 34             Natures Way       35
# 35  Deerfields Gluten Free       36
# 36                  Nakano       37
# 37        Sundown Naturals       38
# 38                Munchies       39
# 39                    Amys       40
# 40             P.f. Changs       41
# 41      Moms Best Naturals       42
# 42                 Ferrara       43
# 43                  Elmers       44
# 44                Kelloggs       45
# 45              Mama Marys       46
# 46              Bear Naked       47
# 47                    Dove       48
# 48                Easy-off       49
# 49                  Choice       50
#
#                                                                                     item_name  \
# 0                                                              Riceland American Jazmine Rice
# 1                                       Caress Velvet Bliss Ultra Silkening Beauty Bar - 6 Ct
# 2                                       Earths Best Organic Fruit Yogurt Smoothie Mixed Berry
# 3                                            Boars Head Sliced White American Cheese - 120 Ct
# 4                                 Back To Nature Gluten Free White Cheddar Rice Thin Crackers
# 5                                        Sally Hansen Nail Color Magnetic 903 Silver Elements
# 6                                           Twinings Of London Classics Lady Grey Tea - 20 Ct
# 7                                          Lea & Perrins Marinade In-a-bag Cracked Peppercorn
# 21        7.31   16000288829   16000288829
# 22        1.78   70670009658   70670009658
# 23        5.34  688267084225  688267084225
# 24        2.43   44100117428   44100117428
# 25        0.98  300436344045  300436344045
# 26        6.01   24600017008   24600017008
# 27        7.52  719175900007  719175900007
# 28        8.65   13000001038   13000001038
# 29        8.39  723503568678  723503568678
# 30        4.21  652790100226  652790100226
# 31        0.68    8500004528    8500004528
# 32        6.52   71463060078   71463060078
# 33        4.17  312546628694  312546628694
# 34        5.19   33674100066   33674100066
# 35        7.95  610358991525  610358991525
# 36        9.59   73575295003   73575295003
# 37        3.45   30768540548   30768540548
# 38        9.02   28400029254   28400029254
# 39        0.60   42272008063   42272008063
# 40        5.62   31000670016   31000670016
# 41        2.97  883978129115  883978129115
# 42        8.40   71403000379   71403000379
# 43        7.06   26000001403   26000001403
# 44        4.40   38000542237   38000542237
# 45        4.65   35457770664   35457770664
# 46        7.38  884623708976  884623708976
# 47        3.72   79400271631   79400271631
# 48        9.54   62338879772   62338879772
# 49        5.20   47445919221   47445919221

# %% [markdown]
# ### 2. Do the same thing, but for stores (https://python.zgulde.net/api/v1/stores)

# %% [markdown]
# ### take away: max_page for this file is 1 so there will be no next page

# %%
def stores():
    # setup
    domain = 'https://python.zgulde.net'
    endpoint = '/api/v1/stores'
    stores = []
    #loop while our endpoint isn't none
    while endpoint != None:
        #create api url
        url = domain + endpoint
        #get data
        response = requests.get(url)
        data = response.json()
        #add data to list
        stores.extend(data['payload']['stores'])
        #grab new endpoint
        endpoint = data['payload']['next_page']
    #save dataframe
    stores = pd.DataFrame(stores)
    return stores
stores()
# Out:
#              store_address   store_city  store_id store_state store_zipcode
# 0   12125 Alamo Ranch Pkwy  San Antonio         1          TX         78253
# 1         9255 FM 471 West  San Antonio         2          TX         78251
# 2  2118 Fredericksburg Rdj  San Antonio         3          TX         78201
# 3          516 S Flores St  San Antonio         4          TX         78204
# 4          1520 Austin Hwy  San Antonio         5          TX         78218
# 5       1015 S WW White Rd  San Antonio         6          TX         78220
# 6   12018 Perrin Beitel Rd  San Antonio         7          TX         78217
# 7      15000 San Pedro Ave  San Antonio         8          TX         78232
# 8       735 SW Military Dr  San Antonio         9          TX         78221
# 9     8503 NW Military Hwy  San Antonio        10          TX         78231

# %% [markdown]
# ### 3. Extract the data for sales (https://python.zgulde.net/api/v1/sales). There are a lot of pages of data here, so your code will need to be a little more complex. Your code should continue fetching data from the next page until all of the data is extracted.

# %%
response = requests.get('https://python.zgulde.net/api/v1/sales')
data = response.json()
data.keys()
# Out:
# dict_keys(['payload', 'status'])

# %%
def sales():
    #initialize variables
    domain = 'https://python.zgulde.net/'
    endpoint = '/api/v1/sales'
    sales = []

    #loop while our endpoint isn't none
    while endpoint != None:
        #create api url
        url = domain + endpoint
        #get data
        response = requests.get(url)
        data = response.json()
        #add data to list
        sales.extend(data['payload']['sales'])
        #grab new endpoint
        endpoint = data['payload']['next_page']

    sales = pd.DataFrame(sales)
    return sales
sales()
# Out:
#         item  sale_amount                      sale_date  sale_id  store
# 0          1         13.0  Tue, 01 Jan 2013 00:00:00 GMT        1      1
# 1          1         11.0  Wed, 02 Jan 2013 00:00:00 GMT        2      1
# 2          1         14.0  Thu, 03 Jan 2013 00:00:00 GMT        3      1
# 3          1         13.0  Fri, 04 Jan 2013 00:00:00 GMT        4      1
# 4          1         10.0  Sat, 05 Jan 2013 00:00:00 GMT        5      1
# ...      ...          ...                            ...      ...    ...
# 912995    50         63.0  Wed, 27 Dec 2017 00:00:00 GMT   912996     10
# 912996    50         59.0  Thu, 28 Dec 2017 00:00:00 GMT   912997     10
# 912997    50         74.0  Fri, 29 Dec 2017 00:00:00 GMT   912998     10
# 912998    50         62.0  Sat, 30 Dec 2017 00:00:00 GMT   912999     10
# 912999    50         82.0  Sun, 31 Dec 2017 00:00:00 GMT   913000     10
#
# [913000 rows x 5 columns]

# %%
sales = sales()
stores = stores()
items = items()

# %% [markdown]
# ### 4. Save the data in your files to local csv files so that it will be faster to access in the future.

# %%
# Write each dataframe to disk
items.to_csv("items.csv", index = False)
stores.to_csv("stores.csv", index = False)

# %%
# Write each dataframe to disk
sales.to_csv("sales.csv", index = False)

# %%
items.head()
# Out:
#        item_brand  item_id  \
# 0        Riceland        1
# 1          Caress        2
# 2     Earths Best        3
# 3      Boars Head        4
# 4  Back To Nature        5
#
#                                                      item_name  item_price  \
# 0                               Riceland American Jazmine Rice        0.84
# 1        Caress Velvet Bliss Ultra Silkening Beauty Bar - 6 Ct        6.44
# 2        Earths Best Organic Fruit Yogurt Smoothie Mixed Berry        2.43
# 3             Boars Head Sliced White American Cheese - 120 Ct        3.14
# 4  Back To Nature Gluten Free White Cheddar Rice Thin Crackers        2.61
#
#      item_upc12    item_upc14
# 0   35200264013   35200264013
# 1   11111065925   11111065925
# 2   23923330139   23923330139
# 3  208528800007  208528800007
# 4  759283100036  759283100036

# %%
stores.head()
# Out:
#              store_address   store_city  store_id store_state store_zipcode
# 0   12125 Alamo Ranch Pkwy  San Antonio         1          TX         78253
# 1         9255 FM 471 West  San Antonio         2          TX         78251
# 2  2118 Fredericksburg Rdj  San Antonio         3          TX         78201
# 3          516 S Flores St  San Antonio         4          TX         78204
# 4          1520 Austin Hwy  San Antonio         5          TX         78218

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 913000 entries, 0 to 912999
# Data columns (total 5 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   item         913000 non-null  int64
#  1   sale_amount  913000 non-null  float64
#  2   sale_date    913000 non-null  object
#  3   sale_id      913000 non-null  int64
#  4   store        913000 non-null  int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 34.8+ MB

# %%
# Run this cell to tell your gitignore to ignore all CSV files 
# The ! in a jupyter notebook is a way to issue commands to the command line
# !echo "*.csv" >> .gitignore

# %% [markdown]
# ### 5. Combine the data from your three separate dataframes into one large dataframe.

# %%
sales_and_stores = pd.merge(sales,stores, how="inner", left_on="store", right_on="store_id")
sales_and_stores.head()
# Out:
#    item  sale_amount                      sale_date  sale_id  store  \
# 0     1         13.0  Tue, 01 Jan 2013 00:00:00 GMT        1      1
# 1     1         11.0  Wed, 02 Jan 2013 00:00:00 GMT        2      1
# 2     1         14.0  Thu, 03 Jan 2013 00:00:00 GMT        3      1
# 3     1         13.0  Fri, 04 Jan 2013 00:00:00 GMT        4      1
# 4     1         10.0  Sat, 05 Jan 2013 00:00:00 GMT        5      1
#
#             store_address   store_city  store_id store_state store_zipcode
# 0  12125 Alamo Ranch Pkwy  San Antonio         1          TX         78253
# 1  12125 Alamo Ranch Pkwy  San Antonio         1          TX         78253
# 2  12125 Alamo Ranch Pkwy  San Antonio         1          TX         78253
# 3  12125 Alamo Ranch Pkwy  San Antonio         1          TX         78253
# 4  12125 Alamo Ranch Pkwy  San Antonio         1          TX         78253

# %%
df = pd.merge(sales_and_stores,items, how = "inner", left_on='item',right_on='item_id')
df.shape
# Out:
# (913000, 16)

# %% [markdown]
# ### 6) Acquire the Open Power Systems Data for Germany, which has been rapidly expanding its renewable energy production in recent years. The data set includes country-wide totals of electricity consumption, wind power production, and solar power production for 2006-2017. You can get the data here: https://raw.githubusercontent.com/jenfly/opsd/master/opsd_germany_daily.csv

# %%
german_power_system = pd.read_csv("https://raw.githubusercontent.com/jenfly/opsd/master/opsd_germany_daily.csv")

# %%
german_power_system
# Out:
#             Date  Consumption     Wind   Solar  Wind+Solar
# 0     2006-01-01   1069.18400      NaN     NaN         NaN
# 1     2006-01-02   1380.52100      NaN     NaN         NaN
# 2     2006-01-03   1442.53300      NaN     NaN         NaN
# 3     2006-01-04   1457.21700      NaN     NaN         NaN
# 4     2006-01-05   1477.13100      NaN     NaN         NaN
# ...          ...          ...      ...     ...         ...
# 4378  2017-12-27   1263.94091  394.507  16.530     411.037
# 4379  2017-12-28   1299.86398  506.424  14.162     520.586
# 4380  2017-12-29   1295.08753  584.277  29.854     614.131
# 4381  2017-12-30   1215.44897  721.247   7.467     728.714
# 4382  2017-12-31   1107.11488  721.176  19.980     741.156
#
# [4383 rows x 5 columns]

# %% [markdown]
# ### 7. Make sure all the work that you have done above is reproducible. That is, you should put the code above into separate functions in the acquire.py file and be able to re-run the functions and get the same data.
