# %%
from cgi import test
from lib2to3.pgen2.pgen import DFAState
from lib2to3.refactor import get_all_fix_names
import numpy as np
import seaborn as sns
import scipy.stats as stats
import pandas as pd
import matplotlib.pyplot as plt
from pydataset import data
import scipy
import os
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
import warnings
warnings.filterwarnings('ignore')
import acquire

# %%
df = acquire.HEB_data()

# %%
df
# Out:
#       item  sale_amount                      sale_date  sale_id  store  \
# 0        1         13.0  Tue, 01 Jan 2013 00:00:00 GMT        1      1
# 1        1         11.0  Wed, 02 Jan 2013 00:00:00 GMT        2      1
# 2        1         14.0  Thu, 03 Jan 2013 00:00:00 GMT        3      1
# 3        1         13.0  Fri, 04 Jan 2013 00:00:00 GMT        4      1
# 4        1         10.0  Sat, 05 Jan 2013 00:00:00 GMT        5      1
# ...    ...          ...                            ...      ...    ...
# 4995     1         23.0  Mon, 05 Sep 2016 00:00:00 GMT     4996      3
# 4996     1         22.0  Tue, 06 Sep 2016 00:00:00 GMT     4997      3
# 4997     1         21.0  Wed, 07 Sep 2016 00:00:00 GMT     4998      3
# 4998     1         22.0  Thu, 08 Sep 2016 00:00:00 GMT     4999      3
# 4999     1         24.0  Fri, 09 Sep 2016 00:00:00 GMT     5000      3
#
#                 store_address   store_city  store_id store_state  \
# 0      12125 Alamo Ranch Pkwy  San Antonio         1          TX
# 1      12125 Alamo Ranch Pkwy  San Antonio         1          TX
# 2      12125 Alamo Ranch Pkwy  San Antonio         1          TX
# 3      12125 Alamo Ranch Pkwy  San Antonio         1          TX
# 4      12125 Alamo Ranch Pkwy  San Antonio         1          TX
# ...                       ...          ...       ...         ...
# 4995  2118 Fredericksburg Rdj  San Antonio         3          TX
# 4996  2118 Fredericksburg Rdj  San Antonio         3          TX
# 4997  2118 Fredericksburg Rdj  San Antonio         3          TX
# 4998  2118 Fredericksburg Rdj  San Antonio         3          TX
# 4999  2118 Fredericksburg Rdj  San Antonio         3          TX
#
#       store_zipcode item_brand  item_id                       item_name  \
# 0             78253   Riceland        1  Riceland American Jazmine Rice
# 1             78253   Riceland        1  Riceland American Jazmine Rice
# 2             78253   Riceland        1  Riceland American Jazmine Rice
# 3             78253   Riceland        1  Riceland American Jazmine Rice
# 4             78253   Riceland        1  Riceland American Jazmine Rice
# ...             ...        ...      ...                             ...
# 4995          78201   Riceland        1  Riceland American Jazmine Rice
# 4996          78201   Riceland        1  Riceland American Jazmine Rice
# 4997          78201   Riceland        1  Riceland American Jazmine Rice
# 4998          78201   Riceland        1  Riceland American Jazmine Rice
# 4999          78201   Riceland        1  Riceland American Jazmine Rice
#
#       item_price   item_upc12   item_upc14
# 0           0.84  35200264013  35200264013
# 1           0.84  35200264013  35200264013
# 2           0.84  35200264013  35200264013
# 3           0.84  35200264013  35200264013
# 4           0.84  35200264013  35200264013
# ...          ...          ...          ...
# 4995        0.84  35200264013  35200264013
# 4996        0.84  35200264013  35200264013
# 4997        0.84  35200264013  35200264013
# 4998        0.84  35200264013  35200264013
# 4999        0.84  35200264013  35200264013
#
# [5000 rows x 16 columns]

# %% [markdown]
# # Exercises
# The end result of this exercise should be a file named prepare.py.
#
# Using your store items data:
#
# 1) Convert date column to datetime format.
#
# 2) Plot the distribution of sale_amount and item_price.
#
# 3) Set the index to be the datetime variable.
#
# 4) Add a 'month' and 'day of week' column to your dataframe.
#
# 5) Add a column to your dataframe, sales_total, which is a derived from sale_amount (total items) and item_price.
#
# 6) Make sure all the work that you have done above is reproducible. That is, you should put the code above into separate functions and be able to re-run the functions and get the same results.
#
#
# Using the OPS data acquired in the Acquire exercises opsd_germany_daily.csv, complete the following:
#
# 1) Convert date column to datetime format.
#
# 2) Plot the distribution of each of your variables.
#
# 3) Set the index to be the datetime variable.
#
# 4) Add a month and a year column to your dataframe.
#
# 5) Fill any missing values.
#
# 6) Make sure all the work that you have done above is reproducible. That is, you should put the code above into separate functions and be able to re-run the functions and get the same results.

# %% [markdown]
# ***

# %% [markdown]
# 1) Convert date column to datetime format.

# %%
df.sale_date = df.sale_date.apply(lambda date: date[:-13])

# %%
df.sale_date = pd.to_datetime(df.sale_date, format='%a, %d %b %Y')

# %% [markdown]
# 2) Plot the distribution of sale_amount and item_price.

# %%
#sale_amount distribution plot
df.sale_amount.hist()
# Out:
# <AxesSubplot:>

# %%
#item_price distribution plot
df.item_price.hist()
# Out:
# <AxesSubplot:>
